# %% [markdown]
# # Exercise: Board Game Geek database

# %% [markdown]
# Download the Board Games SQLite database (Links to an external site.) from Kaggle. Then in Jupyter Notebook, read in the data for each table. Use code to show the number of rows and columns for each table in the database. Upload the notebook with this information to your Github profile and submit the URL.

# %%
#library to use dataframes
import pandas as pd

#library to connect & interact with databases
from sqlalchemy import create_engine, inspect

# %%
#set the database file location to a variable
#had to open up zip file and uploading the file to jupyter
db_file = r'datasets/database.sqlite'

# set the connection to SQLite database in a variable
engine = create_engine(f"sqlite:///{db_file}")

# %%
engine.table_names()
# Out:
# ['BoardGames',
#  'bgg.ldaOut.top.documents',
#  'bgg.ldaOut.top.terms',
#  'bgg.ldaOut.topics',
#  'bgg.topics']

# %%
inspector = inspect(engine)

# %%
print(inspector.get_columns('BoardGames'))
# Out:
# [{'name': 'row_names', 'type': TEXT(), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}, {'name': 'game.id', 'type': TEXT(), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}, {'name': 'game.type', 'type': TEXT(), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}, {'name': 'details.description', 'type': TEXT(), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}, {'name': 'details.image', 'type': TEXT(), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}, {'name': 'details.maxplayers', 'type': INTEGER(), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}, {'name': 'details.maxplaytime', 'type': INTEGER(), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}, {'name': 'details.minage', 'type': INTEGER(), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}, {'name': 'detail
# ...

# %%
boardgames = inspector.get_columns('BoardGames')

# %%
boardgames_names = pd.DataFrame.from_dict(boardgames)
boardgames_names
# Out:
#    autoincrement default                                   name  nullable  \
# 0           auto    None                              row_names      True
# 1           auto    None                                game.id      True
# 2           auto    None                              game.type      True
# 3           auto    None                    details.description      True
# 4           auto    None                          details.image      True
# 5           auto    None                     details.maxplayers      True
# 6           auto    None                    details.maxplaytime      True
# 7           auto    None                         details.minage      True
# 8           auto    None                     details.minplayers      True
# 9           auto    None                    details.minplaytime      True
# 10          auto    None                           details.name      True
# 11          auto    None                    details.playingtime      True
# ...

# %%
bg2 = inspector.get_columns('bgg.ldaOut.top.documents')

# %%
boardgames_2= pd.DataFrame.from_dict(bg2)
boardgames_2
# Out:
#   autoincrement default       name  nullable  primary_key     type
# 0          auto    None  row_names      True            0     TEXT
# 1          auto    None   document      True            0     TEXT
# 2          auto    None      topic      True            0  INTEGER
# 3          auto    None      gamma      True            0     REAL

# %%
 'bgg.ldaOut.topics',
 'bgg.topics'

# %%
bg3 = inspector.get_columns('bgg.ldaOut.top.terms')

# %%
boardgames_3= pd.DataFrame.from_dict(bg3)
boardgames_3
# Out:
#   autoincrement default       name  nullable  primary_key     type
# 0          auto    None  row_names      True            0     TEXT
# 1          auto    None      topic      True            0  INTEGER
# 2          auto    None       term      True            0     TEXT
# 3          auto    None       beta      True            0     REAL

# %%
bg4 = inspector.get_columns('bbgg.ldaOut.topics')

# %%
boardgames_4= pd.DataFrame.from_dict(bg4)
boardgames_4
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
bg5 = inspector.get_columns('bgg.topics')

# %%
boardgames_5= pd.DataFrame.from_dict(bg5)
boardgames_5
# Out:
#    autoincrement default                                      name  nullable  \
# 0           auto    None                                 row_names      True
# 1           auto    None                                   game.id      True
# 2           auto    None                                 game.type      True
# 3           auto    None                        details.maxplayers      True
# 4           auto    None                       details.maxplaytime      True
# 5           auto    None                            details.minage      True
# 6           auto    None                        details.minplayers      True
# 7           auto    None                       details.minplaytime      True
# 8           auto    None                              details.name      True
# 9           auto    None                       details.playingtime      True
# 10          auto    None                     details.yearpublished      True
# ...
